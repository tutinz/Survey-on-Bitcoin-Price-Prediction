# %% [markdown]
# # Survey BTC

# %% [markdown]
# ## Bitcoin price evolution

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Fetch historical data for Bitcoin (BTC-USD)
BTC_Ticker = yf.Ticker("BTC-USD")
BTC_Data = BTC_Ticker.history(period="max")

# Calculate volatility (standard deviation of daily returns)
BTC_Data['Volatility'] = BTC_Data['Close'].pct_change().rolling(window=30).std()

# Plot time series data and its volatility
plt.figure(figsize=(12, 8))

# Plot time series data
plt.subplot(2, 1, 1)
plt.plot(BTC_Data.index, BTC_Data['Close'], color='blue')
plt.title('Bitcoin (BTC-USD) Price Evolution', fontsize=17)
plt.xlabel('Date', fontsize=15)
plt.ylabel('Price (USD)', fontsize=15)
# Out:
# Text(0, 0.5, 'Price (USD)')

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd  # Import pandas

# Fetch historical data for Bitcoin (BTC-USD)
BTC_Ticker = yf.Ticker("BTC-USD")
BTC_Data = BTC_Ticker.history(period="max")

# Calculate volatility (standard deviation of daily returns)
BTC_Data['Volatility'] = BTC_Data['Close'].pct_change().rolling(window=30).std()

# Calculate log prices
BTC_Data['Log_Close'] = np.log(BTC_Data['Close'])

# Halving dates (approximate)
halving_dates = [
#    "2012-11-28",  # 1st halving
    "2016-07-09",  # 2nd halving
    "2020-05-11",  # 3rd halving
    "2024-04-01"   # Estimated 4th halving
]

# Plot time series data, log prices, and volatility
plt.figure(figsize=(12, 10))


# Plot log prices
plt.subplot(3, 1, 2)
plt.plot(BTC_Data.index, BTC_Data['Log_Close'], color='green')
plt.title('Bitcoin (BTC-USD) Log Price Evolution', fontsize=17)
plt.xlabel('Date', fontsize=15)
plt.ylabel('Log(Price)', fontsize=15)

# Highlight halving events
for halving_date in halving_dates:
    plt.axvline(pd.to_datetime(halving_date), color='red', linestyle='--', label=f'Halving {halving_date}')
plt.legend()

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Carico librerie

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carico tabelle

# %%
import pandas as pd

# Load the CSV files into dataframes
df1 = pd.read_csv('tab0BTCSurvey.csv')
df2 = pd.read_csv('tab1BTCSurvey.csv')
df3 = pd.read_csv('tab2BTCSurvey.csv')


# Display the first 5 rows of each dataframe
#print("First CSV Table:")
#print(df1.head())

#print("\nSecond CSV Table:")
#print(df2.head())

# %%
# Count the number of records in each table
count_df1 = df1.shape[0]
count_df2 = df2.shape[0]
count_df3 = df3.shape[0]

# Alternatively, using len()
count_df1 = len(df1)
count_df2 = len(df2)
count_df3 = len(df3)

print(f"Number of records in tab0BTCSurvey.csv: {count_df1}")
print(f"Number of records in tab1BTCSurvey.csv: {count_df2}")
print(f"Number of records in tab2BTCSurvey.csv: {count_df3}")
# Out:
# Number of records in tab0BTCSurvey.csv: 428
# Number of records in tab1BTCSurvey.csv: 398
# Number of records in tab2BTCSurvey.csv: 10

# %%
# Group by 'Year' and count the number of elements (rows) in each year
count_by_year_df1 = df1.groupby('Year').size()
count_by_year_df2 = df2.groupby('Year').size()
count_by_year_df3 = df3.groupby('Year').size()

# Display the counts
print("Number of elements by year in First CSV Table:")
print(count_by_year_df1)

print("\nNumber of elements by year in Second CSV Table:")
print(count_by_year_df2)

print("\nNumber of elements by year in Third CSV Table:")
print(count_by_year_df3)
# Out:
# Number of elements by year in First CSV Table:
# Year
# 2017      2
# 2018     16
# 2019     38
# 2020     55
# 2021     49
# 2022    114
# 2023    154
# dtype: int64
#
# Number of elements by year in Second CSV Table:
# Year
# 2017      2
# 2018     16
# 2019     37
# 2020     46
# 2021     46
# 2022    108
# 2023    143
# dtype: int64
#
# Number of elements by year in Third CSV Table:
# Year
# 2017      1
# 2018     16
# 2019     31
# 2020     43
# 2021     40
# 2022     96
# 2023    126
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by 'Year' and count the number of elements (rows) in each year
count_by_year_df1 = df1.groupby('Year').size()
count_by_year_df2 = df2.groupby('Year').size()
count_by_year_df3 = df3.groupby('Year').size()

# Combine the data into a single dataframe for easier plotting
combined_df = pd.DataFrame({
    'Table 1': count_by_year_df1,
    'Table 2': count_by_year_df2,
    'Table 3': count_by_year_df3
}).fillna(0)  # Fill NaN with 0 for years missing in any table

# Calculate the differences between the tables
combined_df['Discarded by C2'] = combined_df['Table 2'] - combined_df['Table 3']
combined_df['Discarded by C1'] = combined_df['Table 1'] - combined_df['Table 2']

# Plot the stacked histogram
combined_df[['Table 3', 'Discarded by C2', 'Discarded by C1']].plot(
    kind='bar', stacked=True, color=['green', 'orange', 'skyblue'], figsize=(10, 6))

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Number of Records')
plt.title('Number of Included and Discarded Records per Year')
plt.legend(['Included', 'Discarded by C2', 'Discarded by C1'], title='Records')
plt.tight_layout()

# Show the plot
plt.show()

# %%
df = df1

# %%
df = df3

# %% [markdown]
# ## Document Types Distribution

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each document type
document_type_counts = df['Document Type'].value_counts()

# Plot pie chart
plt.figure(figsize=(8, 8))  # Adjust the size of the figure
plt.pie(document_type_counts, labels=document_type_counts.index, autopct='%1.1f%%', startangle=140, textprops={'fontsize': 18})
plt.title('Document Types Distribution', fontsize=19)  # Adjust the title fontsize
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# # Risultati

# %% [markdown]
# ## Ob. Predizione

# %%
import matplotlib.pyplot as plt

# Assuming df2 is your DataFrame
record_count = len(df)
print("Number of records:", record_count)

# Count occurrences of entries that are only 'BTC'
btc_only_count = (df['Ob. Predizione'] == 'BTC').sum()

print("Entries with only BTC:", btc_only_count)

# Calculate the percentage of 'BTC' and 'BTC and other(s)' classes
probabilities = [1 - (btc_only_count / record_count), btc_only_count / record_count]
class_labels = ['BTC and other(s)', 'Only BTC']

# Plot a pie chart
plt.figure(figsize=(6, 6))
plt.pie(probabilities, labels=class_labels, autopct='%1.1f%%', startangle=90, textprops={'fontsize': 14})
plt.title('Obj. Variable', fontsize=18)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# Number of records: 353
# Entries with only BTC: 248

# %% [markdown]
# ## Features

# %%
stacked = df['Features'].str.split(', ', expand=True).stack()

# Count the occurrences of each element
occurrences = stacked.value_counts()

print("Occurrence of elements separated by commas:")
print(occurrences)
# Out:
# Occurrence of elements separated by commas:
# C                  300
# O                  165
# H                  161
# L                  159
# V                  150
#                   ...
# TweetsNumber         1
# PriceVolatility      1
# MoneySupply          1
# 2YrYield             1
# MarketCao            1
# Name: count, Length: 168, dtype: int64

# %%
# Sort the occurrences in descending order
occurrences_sorted = occurrences.sort_values(ascending=False)

# Select the top 100 most occurring elements
top_100_occurrences = occurrences_sorted.head(100)

# Define the number of features per plot
features_per_plot = 25

# Plot the features in four separate graphs
for i in range(4):
    start = i * features_per_plot
    end = start + features_per_plot
    subset = top_100_occurrences.iloc[start:end]

    plt.figure(figsize=(10, 8))
    subset.plot(kind='barh', fontsize=13)
    plt.title(f'Top {start+1} to {end} Most Occurring Features', fontsize=18)
    plt.xlabel('Occurrences', fontsize=16)
    plt.ylabel('Features', fontsize=16)
    plt.gca().invert_yaxis()  # Invert y-axis to display the most frequent element at the top
    plt.show()

# %% [markdown]
# ## Models

# %%
stacked = df['Modelli'].str.split(', ', expand=True).stack()

# Count the occurrences of each element
occurrences = stacked.value_counts()

print("Occurrence of elements separated by commas:")
print(occurrences)
# Out:
# Occurrence of elements separated by commas:
# LSTM       172
# SVM         75
# SA          64
# ARIMA       58
# GRU         52
#           ...
# FFNN         1
# NNAR         1
# DCN          1
# GAM          1
# N-BEATS      1
# Name: count, Length: 134, dtype: int64

# %% [markdown]
# ### Occurrences

# %%
# Sort the occurrences in descending order
occurrences_sorted = occurrences.sort_values(ascending=False)

# Select the top 100 most occurring models
top_100_occurrences = occurrences_sorted.head(100)

# Define the number of models per plot
models_per_plot = 25

# Plot the models in four separate graphs
for i in range(4):
    start = i * models_per_plot
    end = start + models_per_plot
    subset = top_100_occurrences.iloc[start:end]

    plt.figure(figsize=(10, 8))
    subset.plot(kind='barh', fontsize=13)
    plt.title(f'Top {start+1} to {end} Most Occurring Models', fontsize=18)
    plt.xlabel('Occurrences', fontsize=16)
    plt.ylabel('Models', fontsize=16)
    plt.gca().invert_yaxis()  # Invert y-axis to display the most frequent model at the top
    plt.show()

# %% [markdown]
# ### evoluzione temporale

# %%
# Filter data from 2019 onwards
dfEVO = df[df['Year'] >= 2019]

# Split the 'Modelli' column into separate rows
dfEVO_split = dfEVO.assign(Modelli=dfEVO['Modelli'].str.split(', ')).explode('Modelli')

# Group data by year and model, then count occurrences
grouped = dfEVO_split.groupby(['Year', 'Modelli']).size().unstack(fill_value=0)

# %% [markdown]
# da rivedere

# %%
import matplotlib.pyplot as plt

# Define a custom color palette
custom_colors = {
    'ARIMA': 'blue',
    'RF': 'green',
    'SA': 'red',
    'GRU': 'orange',
    'LSTM': 'magenta',
    'SVM': 'black',
    'RNN': 'white',
    'MLP': 'brown',
    'ANN': 'grey',
    # Add more models and their corresponding colors as needed
}

plt.figure(figsize=(15, 8))

for i, year in enumerate(grouped.index):
    top_models = grouped.loc[year].nlargest(4)
    for j, (model, count) in enumerate(top_models.items()):
        plt.bar(year + (j - 1.5) * 0.2, count, width=0.15, color=custom_colors.get(model), edgecolor='black', label=model)

plt.title('Top 4 Most Used Models by Year (2019-2023)', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Occurrences', fontsize=16)
plt.xticks(grouped.index, rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust legend
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), title='Top Models', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Data resolution

# %%
stacked = df['Resolution dataset'].str.split(', ', expand=True).stack()

# Count the occurrences of each element
occurrences = stacked.value_counts()

print("Occurrence of elements separated by commas:")
print(occurrences)
# Out:
# Occurrence of elements separated by commas:
# 1 d        226
# 1 min       23
# 1 h         17
# 5 min        5
# 1 w          3
# 15 min       3
# 1 m          3
# 1 month      3
# 4 h          3
# 30 min       3
# 1 d          1
# 2 min        1
# 2 h          1
# 2 d          1
# 10 min       1
# 10 s         1
# 1d           1
# 3 min        1
# 30 sec       1
# Name: count, dtype: int64

# %%
# Sort the occurrences in descending order
occurrences.sort_values(ascending=False, inplace=True)

# Select the 40 most occurring elements
top_20_occurrences = occurrences.head(10)

# Plot a horizontal bar graph
plt.figure(figsize=(10, 8))
top_20_occurrences.plot(kind='barh')
plt.title('Most Occurring Data Resolution', fontsize=16)  # Increase title font size
plt.xlabel('Occurrences', fontsize=15)  # Increase x-label font size
plt.ylabel('Resolution', fontsize=15)  # Increase y-label font size
plt.xticks(fontsize=13)  # Increase x-axis tick label font size
plt.yticks(fontsize=13)  # Increase y-axis label font size
plt.gca().invert_yaxis()  # Invert y-axis to display the most frequent element at the top
plt.show()

# %% [markdown]
# ## Sources

# %%
stacked = df['Source'].str.split(', ', expand=True).stack()

# Count the occurrences of each element
occurrences = stacked.value_counts()

print("Occurrence of elements separated by commas:")
print(occurrences)
# Out:
# Occurrence of elements separated by commas:
# yahoo.com                         51
# coinmarketcap.com                 40
# kaggle.com                        31
# investing.com                     22
# binance.com                       17
# coindesk.com                      13
# quandl.com                        13
# cryptocompare.com                 10
# bitcoincharts.com                 10
# blockchain.com                     9
# google.com                         7
# coinbase.com                       7
#                                    7
# cryptodatadownload.com             6
# kraken.com                         4
# reddit.com                         3
# blockchain.info                    3
# bitinfocharts.com                  3
# poloniex.com                       3
# glassnode.com                      3
# bitcoin.org                        2
# nasdaq.com                         2
# bitfinex.com                       2
# bitstamp.com                       2
# gold.org                           2
# marketwatch.com                    2
# bitcoinity.org                     2
# Bitcoinity.org                     2
# cointelegraph.com                  1
# coinmetrics.io                     1
# upbit.com                          1
# data.cryptocompare.com             1
# newsapi.org                        1
# huobi.com                          1
# bitcoininfocharts.com              1
# coinmetrics.com                    1
# ggogle.com                         1
# wikipedia.com                      1
# facebook.com                       1
# twelvedata.com                     1
# bitmex.com                         1
# cryptodatadowload.com              1
# bicoincharts.com                   1
# bitcointalk.com                    1
# Rbitcoincharts.com                 1
# lseg.com                           1
# coingecko.com                      1
#  yahoo.com                         1
# datahub.io                         1
# Blockchain.info                    1
# macrotrends.net                    1
# alphavantage.co                    1
# BTC.com                            1
# tiingo.com                         1
# bloomberg.com                      1
# walletexplorer.com                 1
# tradingview.com                    1
# ft.com                             1
# blochchain-research-center.com     1
# Name: count, dtype: int64

# %%
# Sort the occurrences in descending order and select the top 20
occurrences_sorted = occurrences.sort_values(ascending=False).head(10)

# Plot a horizontal bar graph
plt.figure(figsize=(10, 8))
occurrences_sorted.plot(kind='barh')
plt.title('Top 10 Most Occurring Data Sources Websites', fontsize=16)  # Increase title font size
plt.xlabel('Occurrences', fontsize=14)  # Increase x-label font size
plt.ylabel('Data sources websites', fontsize=14)  # Increase y-label font size
plt.xticks(fontsize=13)  # Increase x-axis tick label font size
plt.yticks(fontsize=13)  # Increase y-axis label font size
plt.gca().invert_yaxis()  # Invert y-axis to display the most frequent element at the top
plt.show()

# %% [markdown]
# Sistemare occorrenza missing!!!!!!!!!!!!!!!!!

# %% [markdown]
# ## Heat map dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Split the 'Date_Range' column into 'Start_Date' and 'End_Date'
df[['Start_Date', 'End_Date']] = df['Range dataset'].str.split(' - ', expand=True)

# %%
# Drop rows with missing values in 'Start_Date' and 'End_Date' columns only
df = df.dropna(subset=['Start_Date', 'End_Date'])

# Convert date columns to datetime objects
df['Start_Date'] = pd.to_datetime(df['Start_Date'], dayfirst=True, format='mixed')
df['End_Date'] = pd.to_datetime(df['End_Date'], dayfirst=True, format='mixed', errors='coerce')

# Extract year and month from dates
df['Start_Year'] = df['Start_Date'].dt.year
df['End_Year'] = df['End_Date'].dt.year
df['Start_Month'] = df['Start_Date'].dt.month
df['End_Month'] = df['End_Date'].dt.month
# Out:
# <ipython-input-57-aa8e16166d66>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Start_Date'] = pd.to_datetime(df['Start_Date'], dayfirst=True, format='mixed')
# <ipython-input-57-aa8e16166d66>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['End_Date'] = pd.to_datetime(df['End_Date'], dayfirst=True, format='mixed', errors='coerce')
# <ipython-input-57-aa8e16166d66>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Start_Year'] = df['Start_Date'].dt.year
# <ipython-input-57-aa8e16166d66>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['End_Year'] = df['End_Date'].dt.year
# <ipython-input-57-aa8e16166d66>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Start_Month'] = df['Start_Date'].dt.month
# <ipython-input-57-aa8e16166d66>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['End_Month'] = df['End_Date'].dt.month

# %%
from sklearn.neural_network import BernoulliRBM

# %%
df.fillna(0)
# Out:
#                                                Authors  \
# 0    Oyedele A.A.; Ajayi A.O.; Oyedele L.O.; Bello ...
# 1              Seabe P.L.; Moutsinga C.R.B.; Pindza E.
# 2                                              Chen J.
# 3                              Sun X.; Liu M.; Sima Z.
# 4                               Chen Z.; Li C.; Sun W.
# ..                                                 ...
# 347        Modi P.D.; Arshi K.; Kunz P.J.; Zoubir A.M.
# 348        Singh M.; Jakhar A.K.; Juneja A.; Pandey S.
# 350       Prusti D.; Tripathy A.K.; Sahu R.; Rath S.K.
# 351  Malla J.; Lavanya C.; Jayashree J.; Vijayashre...
# 352  Hegde M.S.D.; Bhat M.; Horapeti U.; Manoj D.M....
#
#                                                  Title  Year  Cited by Score  \
# 0    Performance evaluation of deep learning and bo...  2023        39  39,0
# 1    Forecasting Cryptocurrency Prices Using LSTM, ...  2023        25  25,0
# 2    Analysis of Bitcoin Price Prediction Using Mac...  2023        20  20,0
# 3    A novel cryptocurrency price trend forecasting...  2020       271  16,9
# 4    Bitcoin price prediction using machine learnin...  2020       214  13,4
# ..                                                 ...   ...       ...   ...
# 347  A Data-driven Deep Learning Approach for Bitco...  2023         0   0,0
# 348  Machine Learning Based Framework for Cryptocur...  2023         0   0,0
# 350  Bitcoin Price Prediction by Applying Machine L...  2023         0   0,0
# 351  Bidirectional Gated Recurrent Unit (BiGRU)-Bas...  2023         0   0,0
# 352  Bitcoin Investopedia - Market and Price Predic...  2023         0   0,0
#
#         Document Type                 Ob. Predizione  \
# 0             Article  BTC, ETH, BNB, LTC, XLM, DOGE
# 1             Article                  BTC, ETH, LTC
# 2             Article                            BTC
# 3             Article                    BTC, others
# 4             Article                            BTC
# ..                ...                            ...
# 347  Conference paper                            BTC
# 348  Conference paper                            BTC
# 350  Conference paper                            BTC
# 351  Conference paper                            BTC
# 352  Conference paper                            BTC
#
#                                               Features  \
# 0                              O, H, L, C, V, SMA, EMA
# 1                                     O, H, L, C, AdjC
# 2    O, H, L, C, V, ActiveAddr, MeanTrxSize, TrxFee...
# 3    DJ, S&P500, HangSengI, USD, ShanghaiStockI, Sh...
# 4    BlockSize, H-R, Diff, TrxNumber, ConfirmedTrx,...
# ..                                                 ...
# 347                           O, H, L, C, RSI, EMA, BB
# 348                           O, H, L, C, V, MarketCap
# 350                                      O, H, L, C, V
# 351                      SentimentScore, H, L, O, C, V
# 352                    O, H, L, C, EMA, TrxNumber, SMA
#
#                               Modelli  \
# 0       ADAB, GBM, XGB, MLP, GRU, CNN
# 1                  LSTM, GRU, Bi-LSTM
# 2                            LSTM, RF
# 3                   LightGBM, SVM, RF
# 4    LSTM, QDA, SVM, RF, XGB, LR, LDA
# ..                                ...
# 347                           Bi-LSTM
# 348            ARIMA, DT, RF, PROPHET
# 350     ARIMA, LSTM, PROPHET, SVM, LR
# 351               Bi-GRU, SA, Bi-LSTM
# 352                     LR, SVM, LSTM
#
#                          Metriche di valutazione (BTC)  ...  \
# 0                                          MAPE = 1-5%  ...
# 1                 RMSE = 1031-1280; MAPE = 0,036-0,057  ...
# 2    MAPE = 3,3-4,7%, RMSE = 1,7-5,1%, DA = 48,1-52,5%  ...
# 3                                    Accuracy = 48-62%  ...
# 4    Accuracy = 48-66%, Precision =49-72%, Recall =...  ...
# ..                                                 ...  ...
# 347                                    RMSE, MAE, MAPE  ...
# 348                                    RMSE, MAE, MAPE  ...
# 350                                MAPE, MSE, RMSE, R2  ...
# 351                    Accuracy, Precision, Recall, F1  ...
# 352                                     MAE, MSE, RMSE  ...
#
#                Range dataset Resolution dataset  \
# 0    01/01/2018 - 02/03/2022                1 d
# 1    01/01/2018 - 01/01/2023                1 d
# 2    31/03/2015 - 01/04/2022                1 d
# 3    01/01/2018 - 30/06/2018                1 d
# 4    02/02/2017 - 01/02/2019         1 d, 5 min
# ..                       ...                ...
# 347  01/01/2013 - 30/09/2021                  0
# 348  01/09/2014 - 31/03/2022                1 d
# 350  01/01/2015 - 31/12/2018                1 d
# 351  01/01/2021 - 31/12/2021                  0
# 352  01/08/2014 - 30/11/2022                1 d
#
#                                                 Source  \
# 0               yahoo.com, bitfinex.com, investing.com
# 1                                            yahoo.com
# 2    yahoo.com, investing.com, coinmarketcap.com, b...
# 3                                        investing.com
# 4                    coinmarketcap.com, Bitcoinity.org
# ..                                                 ...
# 347                                                  0
# 348                                  coinmarketcap.com
# 350                                          yahoo.com
# 351                                  coinmarketcap.com
# 352                                          yahoo.com
#
#                                                   Note Start_Date  \
# 0                           GA x ottimizzare parametri 2018-01-01
# 1                                                    0 2018-01-01
# 2                          Grafico importanza features 2015-03-31
# 3                                                    0 2018-01-01
# 4    Differenti modelli per differenti frequenze, g... 2017-02-02
# ..                                                 ...        ...
# 347                                                  0 2013-01-01
# 348                                                  0 2014-09-01
# 350                                                  0 2015-01-01
# 351                                                  0 2021-01-01
# 352                                                  0 2014-08-01
#
#                 End_Date Start_Year End_Year  Start_Month  End_Month
# 0    2022-03-02 00:00:00       2018   2022.0            1        3.0
# 1    2023-01-01 00:00:00       2018   2023.0            1        1.0
# 2    2022-04-01 00:00:00       2015   2022.0            3        4.0
# 3    2018-06-30 00:00:00       2018   2018.0            1        6.0
# 4    2019-02-01 00:00:00       2017   2019.0            2        2.0
# ..                   ...        ...      ...          ...        ...
# 347  2021-09-30 00:00:00       2013   2021.0            1        9.0
# 348  2022-03-31 00:00:00       2014   2022.0            9        3.0
# 350  2018-12-31 00:00:00       2015   2018.0            1       12.0
# 351  2021-12-31 00:00:00       2021   2021.0            1       12.0
# 352  2022-11-30 00:00:00       2014   2022.0            8       11.0
#
# [247 rows x 22 columns]

# %%
# Drop rows with missing values in relevant columns
df = df.dropna(subset=['Start_Year', 'End_Year', 'Start_Month', 'End_Month'])

# Convert the remaining columns to integers
df[['Start_Year', 'End_Year', 'Start_Month', 'End_Month']] = \
    df[['Start_Year', 'End_Year', 'Start_Month', 'End_Month']].astype(int)

# Debug: Print the range of years
print("Year range:", df['Start_Year'].min(), df['End_Year'].max())

# Create a new DataFrame to hold the occurrences
occurrences = pd.DataFrame(index=range(df['Start_Year'].min(), df['End_Year'].max() + 1),
                           columns=range(1, 13)).fillna(0)

# Iterate through the rows of the original DataFrame and update occurrences
for _, row in df.iterrows():
    try:
      start_year = row['Start_Year']
      end_year = row['End_Year']
      start_month = row['Start_Month']
      end_month = row['End_Month']

      if start_year == end_year:
          occurrences.loc[start_year, start_month:end_month] += 1
      else:
          occurrences.loc[start_year, start_month:] += 1
          occurrences.loc[end_year, :end_month] += 1
          if end_year > start_year + 1:
              for year in range(start_year + 1, end_year):
                  occurrences.loc[year, :] += 1
    except Exception as e:
        print(f"Error processing row: {e}")
        continue
# Plotting
plt.figure(figsize=(10, 6))
plt.imshow(occurrences, cmap='viridis', aspect='auto')
plt.colorbar(label='Occurrences')
plt.title('Most Studied Interval of Times')
plt.xlabel('Month')
plt.ylabel('Year')
plt.xticks(ticks=range(12), labels=range(1, 13))
plt.yticks(ticks=range(len(occurrences.index)), labels=occurrences.index)
plt.show()
# Out:
# Year range: 2009 2023
# <ipython-input-59-0925f3d3c26f>:13: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   columns=range(1, 13)).fillna(0)
# Error processing row: 2028

# %% [markdown]
# ...
